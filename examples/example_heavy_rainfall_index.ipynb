# %% [markdown]
# # Example for Heavy Rainfall Index

# %% [markdown]
# Based on the IntensityDurationFrequencyAnalysis, the HeavyRainIndexAnalysis enables the creation of location-dependent heavy rain indices according to the methods of Schmitt, Mudersbach and also those of Krüger and Pfister.
# Furthermore, the possibility of creating heavy rain index curves according to the Krüger and Pfister method was included and implemented for the other two methods. Thus, heavy rainfall index curves can be compared with each other. Furthermore, it is possible to assign individual rain events to a heavy rain index using existing rain data.

# %%
from matplotlib.colors import ListedColormap
from idf_analysis.definitions import METHOD, SERIES, COL
from idf_analysis.little_helpers import minutes_readable
from idf_analysis.sww_utils import rain_events, event_duration, agg_events
from idf_analysis.heavy_rainfall_index import HeavyRainfallIndexAnalyse
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os import path

# %matplotlib inline
plt.style.use('fast')

# %% [markdown]
# Implemented Methods for the HeavyRainIndexAnalysis:
# SCHMITT = 'Schmitt'
# KRUEGER_PFISTER = 'KruegerPfister'
# MUDERSBACH = 'Mudersbach'

# %%
hri = HeavyRainfallIndexAnalyse(method=HeavyRainfallIndexAnalyse.METHODS.KRUEGER_PFISTER,
                                series_kind=SERIES.PARTIAL, worksheet=METHOD.KOSTRA, extended_durations=True)

# %%
cmap = ListedColormap([(1,1,1)] + list(hri.indices_color.values()))

# %%
data = pd.read_parquet('ehyd_112086.parquet').squeeze('columns')

# %%
output_directory = 'Ergebnisse'

# %%
hri.set_series(data)

# %%
hri.auto_save_parameters(path.join(output_directory, 'idf_parameters.yaml'))
# Out:
# Calculating Parameters u and w:   0%|          | 0/21 [00:00<?, ?it/s]
# _balance_parameter_change

# %% [markdown]
# Heavy rainfall index-matrix is created with regard to the individual procedures for SRI generation

# %%
hri.interim_sri_table().style.background_gradient(cmap=cmap, vmin=1, vmax=12)
# Out:
# <style type="text/css">
# #T_9af2a_row0_col0, #T_9af2a_row0_col1, #T_9af2a_row0_col2, #T_9af2a_row0_col3, #T_9af2a_row0_col4, #T_9af2a_row0_col5, #T_9af2a_row0_col6, #T_9af2a_row0_col7, #T_9af2a_row0_col8, #T_9af2a_row0_col9, #T_9af2a_row0_col10, #T_9af2a_row1_col0, #T_9af2a_row1_col1, #T_9af2a_row1_col2, #T_9af2a_row1_col3, #T_9af2a_row1_col4, #T_9af2a_row1_col5, #T_9af2a_row1_col6, #T_9af2a_row1_col7, #T_9af2a_row2_col0, #T_9af2a_row2_col1, #T_9af2a_row2_col2, #T_9af2a_row2_col3, #T_9af2a_row2_col4, #T_9af2a_row2_col5, #T_9af2a_row3_col0, #T_9af2a_row3_col1, #T_9af2a_row3_col2, #T_9af2a_row3_col3, #T_9af2a_row3_col4, #T_9af2a_row4_col0, #T_9af2a_row4_col1, #T_9af2a_row4_col2, #T_9af2a_row4_col3, #T_9af2a_row4_col4, #T_9af2a_row5_col0, #T_9af2a_row5_col1, #T_9af2a_row5_col2, #T_9af2a_row5_col3, #T_9af2a_row6_col0, #T_9af2a_row6_col1, #T_9af2a_row6_col2, #T_9af2a_row6_col3, #T_9af2a_row7_col0, #T_9af2a_row7_col1, #T_9af2a_row7_col2, #T_9af2a_row7_col3, #T_9af2a_row8_col0, #T_9af2a_row
#   background-color: #e6ff4c;
#   color: #000000;
# }
# #T_9af2a_row5_col10, #T_9af2a_row6_col9, #T_9af2a_row6_col10, #T_9af2a_row7_col9, #T_9af2a_row8_col9, #T_9af2a_row9_col8, #T_9af2a_row10_col8, #T_9af2a_row11_col8, #T_9af2a_row12_col7, #T_9af2a_row13_col7, #T_9af2a_row14_col6, #T_9af2a_row14_col7, #T_9af2a_row15_col6, #T_9af2a_row15_col7, #T_9af2a_row16_col5, #T_9af2a_row16_col6, #T_9af2a_row17_col5, #T_9af2a_row19_col4, #T_9af2a_row20_col4 {
#   background-color: #fff500;
#   color: #000000;
# }
# #T_9af2a_row7_col10, #T_9af2a_row8_col10, #T_9af2a_row9_col9, #T_9af2a_row9_col10, #T_9af2a_row10_col9, #T_9af2a_row10_col10, #T_9af2a_row11_col9, #T_9af2a_row12_col8, #T_9af2a_row12_col9, #T_9af2a_row13_col8, #T_9af2a_row14_col8, #T_9af2a_row15_col8, #T_9af2a_row16_col7, #T_9af2a_row17_col6, #T_9af2a_row17_col7, #T_9af2a_row18_col5 {
#   background-color: #ffa100;
#   color: #000000;
# }
# #T_9af2a_row11_col10, #T_9af2a_row12_col10, #T_9af2a_row13_col9, #T_9af2a_row13_col10, #T_9af2a_row14_col9, #T_9af2a_row15_col9, #T_9af2a_row16_col8, #T_9af2a_row18_col6, #T_9af2a_row18_col7, #T_9af2a_row19_col5, #T_9af2a_row19_col6, #T_9af2a_row20_col5 {
#   background-color: #ff2900;
#   color: #f1f1f1;
# }
# #T_9af2a_row14_col10, #T_9af2a_row15_col10, #T_9af2a_row16_col9, #T_9af2a_row16_col10, #T_9af2a_row17_col8, #T_9af2a_row19_col7, #T_9af2a_row20_col6, #T_9af2a_row20_col7 {
#   background-color: #f71f3d;
#   color: #f1f1f1;
# }
# #T_9af2a_row17_col9, #T_9af2a_row18_col8, #T_9af2a_row19_col8 {
#   background-color: #ff1a63;
#   color: #f1f1f1;
# }
# #T_9af2a_row17_col10, #T_9af2a_row18_col9, #T_9af2a_row20_col8 {
#   background-color: #f70882;
#   color: #f1f1f1;
# }
# #T_9af2a_row18_col10, #T_9af2a_row19_col9 {
#   background-color: #eb14bf;
#   color: #f1f1f1;
# }
# #T_9af2a_row19_col10, #T_9af2a_row20_col9, #T_9af2a_row20_col10 {
#   background-color: #a81cdb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9af2a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Return Period in a</th>
#       <th id="T_9af2a_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_9af2a_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_9af2a_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_9af2a_level0_col3" class="col_heading level0 col3" >5</th>
#       <th id="T_9af2a_level0_col4" class="col_heading level0 col4" >10</th>
#       <th id="T_9af2a_level0_col5" class="col_heading level0 col5" >20</th>
#       <th id="T_9af2a_level0_col6" class="col_heading level0 col6" >25</th>
#       <th id="T_9af2a_level0_col7" class="col_heading level0 col7" >30</th>
#       <th id="T_9af2a_level0_col8" class="col_heading level0 col8" >50</th>
#       <th id="T_9af2a_level0_col9" class="col_heading level0 col9" >75</th>
#       <th id="T_9af2a_level0_col10" class="col_heading level0 col10" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0"
#   background-color: #ccff99;
#   color: #000000;
# }
# #T_72639_row17_col10, #T_72639_row17_col11, #T_72639_row18_col9, #T_72639_row18_col10, #T_72639_row18_col11, #T_72639_row19_col8, #T_72639_row19_col9, #T_72639_row19_col10, #T_72639_row19_col11, #T_72639_row20_col8, #T_72639_row20_col9, #T_72639_row20_col10, #T_72639_row20_col11 {
#   background-color: #e6ff4c;
#   color: #000000;
# }
# </style>
# <table id="T_72639">
#   <thead>
#     <tr>
#       <th class="index_name level0" >SRI</th>
#       <th id="T_72639_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_72639_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_72639_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_72639_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_72639_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_72639_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_72639_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_72639_level0_col7" class="col_heading level0 col7" >8</th>
#       <th id="T_72639_level0_col8" class="col_heading level0 col8" >9</th>
#       <th id="T_72639_level0_col9" class="col_heading level0 col9" >10</th>
#       <th id="T_72639_level0_col10" class="col_heading level0 col10" >11</th>
#       <th id="T_72639_level0_col11" class="col_heading level0 col11" >12</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >duration in min</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72639_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_72639_row0_col0" class="data row0 col0" >17.9</td>
#       <td id="T_72639_row0_col1" class="data row0 col1" >25.2</td>
#       <td id="T_72639_row0_col2" class="data row0 col2" >30.9</td>
#       <td id="T_72639_row0_col3" class="data row0 col3" >35.7</td>
#       <td id="T_72639_row0_col4" class="data row0 col4" >39.9</td>
#       <td id="T_72639_row0_col5" class="data row0 col5" >43.7</td>
#       <td id="T_72639_row0_col6" class="data row0 col6" >47.2</td>
#       <td id="T_72639_row0_col7" class="data row0 col7" >50.5</td>
#       <td id="T_72639_row0_col8" class="data row0 col8" >53.6</td>
#       <td id="T_72639_row0_col9" class="data row0 col9" >56.5</td>
#       <td id="T_72639_row0_col10" class="data row0 col10" >59.2</td>
#       <td id="T_72639_row0_col11" class="data row0 col11" >61.8</td>
#     </tr>
#     <tr>
#       <th id="T_72639_level0_row1"

# %% [markdown]
# Using heavy rainfall index curves, the necessary rainfall heights can be read off depending on the respective index.

# %%
hri.method = hri.METHODS.KRUEGER_PFISTER
fig, ax = hri.result_sri_figure()
ax.legend(loc='upper left')
ax.grid(color='grey', linestyle='-', linewidth=0.3)
ax.set_ylim(0, 230)
old_labels = ax.get_xticklabels()
old_labels[2] = ''
old_labels[5] = ''
old_labels[19] = ''
ax.set_xticklabels(old_labels)
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[::-1], labels[::-1], title='SRI', loc='upper left')
plt.savefig("kruegerpfister.svg")

# %% [markdown]
# Heavy rain index allocation of a specific rain event

# %%
events = rain_events(hri.series, min_gap=pd.Timedelta(days=2))
events[COL.DUR] = event_duration(events)
events[COL.LP] = agg_events(events, hri.series, 'sum').round(1)
events[COL.LAST] = events[COL.START] - events[COL.END].shift()

hri.add_max_return_periods_to_events(events)

events = events[events[COL.LP] > 10]
events = events[events[COL.MAX_PERIOD] > 2]

events.sort_values(COL.LP)
# Out:
# calculating rainfall_sum data-frame:   0%|          | 0/21 [00:00<?, ?it/s]
# calculating return_periods data-frame:   0%|          | 0/21 [00:00<?, ?it/s]
# /Users/markus/PycharmProjects/intensity_duration_frequency_analysis/idf_analysis/idf_class.py:637: FutureWarning: The behavior of DataFrame.idxmax with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#
# 282  2009-08-28 23:41:00 2009-08-29 00:42:00 0 days 01:01:00      49.3
# 544  2011-08-03 19:53:00 2011-08-04 07:44:00 0 days 11:51:00      54.7
# 1532 2018-06-13 14:58:00 2018-06-13 22:27:00 0 days 07:29:00      63.5
#
#           last_event  max_return_period  max_return_period_duration
# 773  0 days 08:18:00          40.647557                      2880.0
# 772  0 days 17:31:00          38.092370                      2880.0
# 282  1 days 03:44:00          21.185639                        20.0
# 544  1 days 23:11:00          13.694970                        20.0
# 1532 0 days 21:27:00          12.150533                        15.0

# %%
event = hri.rain_events.loc[797].copy()

event[COL.START] = pd.to_datetime('2013-05-06 20:00:00')
event
# Out:
# start                         2013-05-06 20:00:00
# end                           2013-06-22 15:59:00
# duration                          0 days 00:59:00
# rain_sum                                      1.6
# last_event                        6 days 13:51:00
# max_return_period                        0.087558
# max_return_period_duration                   60.0
# Name: 797, dtype: object

# %%
rainfall_sum_frame = hri.rainfall_sum_frame[event[COL.START]:event[COL.END]]
return_periods_frame = hri.return_periods_frame[event[COL.START]:event[COL.END]]
# Out:
# calculating rainfall_sum data-frame:   0%|          | 0/21 [00:00<?, ?it/s]

# %%
rainfall_sum_frame.\
    max().\
    rename('max. Regensumme').\
    to_frame().\
    rename(minutes_readable).\
    style.bar(vmin=0, vmax=100).format("{:.1f}")
# Out:
# <style type="text/css">
# #T_ac16e_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.9%, transparent 9.9%);
# }
# #T_ac16e_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.3%, transparent 16.3%);
# }
# #T_ac16e_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.9%, transparent 21.9%);
# }
# #T_ac16e_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 28.2%, transparent 28.2%);
# }
# #T_ac16e_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 40.7%, transparent 40.7%);
# }
# #T_ac16e_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 46.3%, transparent 46.3%);
# }
# #T_ac16e_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 57.0%, transparent 57.0%);
# }
# #T_ac16e_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 69.6%, transparent 69.6%);
# }
# #T_ac16e_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 74.3%, transparent 74.3%);
# }
# #T_ac16e_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 76.5%, transparent 76.5%);
# }
# #T_ac16e_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 78.7%, transparent 78.7%);
# }
# #T_ac16e_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 89.6%, transparent 89.6%);
# }
# #T_ac16e_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 92.8%, transparent 92.8%);
# }
# #T_ac16e_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 93.0%, transparent 93.0%);
# }
# #T_ac16e_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 96.4%, transparent 96.4%);
# }
# #T_ac16e_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.2%, transparent 98.2%);
# }
# #T_ac16e_row16_col0, #T_ac16e_row17_col0, #T_ac16e_row18_col0, #T_ac16e_row19_col0, #T_ac16e_row20_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_ac16e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac16e_level0_col0" class="col_heading level0 col0" >max. Regensumme</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac16e_level0_row0" class="row_heading level0 row0" >5 min</th>
#       <td id="T_ac16e_row0_col0" class="data row0 col0" >9.9</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row1" class="row_heading level0 row1" >10 min</th>
#       <td id="T_ac16e_row1_col0" class="data row1 col0" >16.3</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row2" class="row_heading level0 row2" >15 min</th>
#       <td id="T_ac16e_row2_col0" class="data row2 col0" >21.9</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row3" class="row_heading level0 row3" >20 min</th>
#       <td id="T_ac16e_row3_col0" class="data row3 col0" >28.2</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row4" class="row_heading level0 row4" >30 min</th>
#       <td id="T_ac16e_row4_col0" class="data row4 col0" >40.7</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row5" class="row_heading level0 row5" >45 min</th>
#       <td id="T_ac16e_row5_col0" class="data row5 col0" >46.3</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row6" class="row_heading level0 row6" >60 min</th>
#       <td id="T_ac16e_row6_col0" class="data row6 col0" >57.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row7" class="row_heading level0 row7" >1.5 h</th>
#       <td id="T_ac16e_row7_col0" class="data row7 col0" >69.6</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row8" class="row_heading level0 row8" >2 h</th>
#       <td id="T_ac16e_row8_col0" class="data row8 col0" >74.3</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row9" class="row_heading level0 row9" >3 h</th>
#       <td id="T_ac16e_row9_col0" class="data row9 col0" >76.5</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row10" class="row_heading level0 row10" >4 h</th>
#       <td id="T_ac16e_row10_col0" class="data row10 col0" >78.7</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row11" class="row_heading level0 row11" >6 h</th>
#       <td id="T_ac16e_row11_col0" class="data row11 col0" >89.6</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row12" class="row_heading level0 row12" >9 h</th>
#       <td id="T_ac16e_row12_col0" class="data row12 col0" >92.8</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row13" class="row_heading level0 row13" >12 h</th>
#       <td id="T_ac16e_row13_col0" class="data row13 col0" >93.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row14" class="row_heading level0 row14" >18 h</th>
#       <td id="T_ac16e_row14_col0" class="data row14 col0" >96.4</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row15" class="row_heading level0 row15" >1 d</th>
#       <td id="T_ac16e_row15_col0" class="data row15 col0" >98.2</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row16" class="row_heading level0 row16" >2 d</th>
#       <td id="T_ac16e_row16_col0" class="data row16 col0" >120.5</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row17" class="row_heading level0 row17" >3 d</th>
#       <td id="T_ac16e_row17_col0" class="data row17 col0" >138.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row18" class="row_heading level0 row18" >4 d</th>
#       <td id="T_ac16e_row18_col0" class="data row18 col0" >138.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row19" class="row_heading level0 row19" >5 d</th>
#       <td id="T_ac16e_row19_col0" class="data row19 col0" >143.7</td>
#     </tr>
#     <tr>
#       <th id="T_ac16e_level0_row20" class="row_heading level0 row20" >6 d</th>
#       <td id="T_ac16e_row20_col0" class="data row20 col0" >148.2</td>
#     </tr>
#   </tbody>
# </table>

# %%
return_periods_frame.\
    max().\
    rename('max. Wiederkehrperiode').\
    to_frame().\
    rename(minutes_readable).\
    style.bar(vmin=0, vmax=100).format("{:.1f}")
# Out:
# <style type="text/css">
# #T_8c649_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.4%, transparent 1.4%);
# }
# #T_8c649_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.6%, transparent 1.6%);
# }
# #T_8c649_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.1%, transparent 2.1%);
# }
# #T_8c649_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.4%, transparent 3.4%);
# }
# #T_8c649_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.4%, transparent 8.4%);
# }
# #T_8c649_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.6%, transparent 6.6%);
# }
# #T_8c649_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.2%, transparent 10.2%);
# }
# #T_8c649_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.4%, transparent 21.4%);
# }
# #T_8c649_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.6%, transparent 24.6%);
# }
# #T_8c649_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.7%, transparent 20.7%);
# }
# #T_8c649_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.1%, transparent 19.1%);
# }
# #T_8c649_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 29.3%, transparent 29.3%);
# }
# #T_8c649_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 25.2%, transparent 25.2%);
# }
# #T_8c649_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.6%, transparent 19.6%);
# }
# #T_8c649_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.2%, transparent 20.2%);
# }
# #T_8c649_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.3%, transparent 19.3%);
# }
# #T_8c649_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 40.7%, transparent 40.7%);
# }
# #T_8c649_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 39.8%, transparent 39.8%);
# }
# #T_8c649_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.2%, transparent 16.2%);
# }
# #T_8c649_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.0%, transparent 14.0%);
# }
# #T_8c649_row20_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.5%, transparent 12.5%);
# }
# </style>
# <table id="T_8c649">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c649_level0_col0" class="col_heading level0 col0" >max. Wiederkehrperiode</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c649_level0_row0" class="row_heading level0 row0" >5 min</th>
#       <td id="T_8c649_row0_col0" class="data row0 col0" >1.4</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row1" class="row_heading level0 row1" >10 min</th>
#       <td id="T_8c649_row1_col0" class="data row1 col0" >1.6</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row2" class="row_heading level0 row2" >15 min</th>
#       <td id="T_8c649_row2_col0" class="data row2 col0" >2.1</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row3" class="row_heading level0 row3" >20 min</th>
#       <td id="T_8c649_row3_col0" class="data row3 col0" >3.4</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row4" class="row_heading level0 row4" >30 min</th>
#       <td id="T_8c649_row4_col0" class="data row4 col0" >8.4</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row5" class="row_heading level0 row5" >45 min</th>
#       <td id="T_8c649_row5_col0" class="data row5 col0" >6.6</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row6" class="row_heading level0 row6" >60 min</th>
#       <td id="T_8c649_row6_col0" class="data row6 col0" >10.2</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row7" class="row_heading level0 row7" >1.5 h</th>
#       <td id="T_8c649_row7_col0" class="data row7 col0" >21.4</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row8" class="row_heading level0 row8" >2 h</th>
#       <td id="T_8c649_row8_col0" class="data row8 col0" >24.6</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row9" class="row_heading level0 row9" >3 h</th>
#       <td id="T_8c649_row9_col0" class="data row9 col0" >20.7</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row10" class="row_heading level0 row10" >4 h</th>
#       <td id="T_8c649_row10_col0" class="data row10 col0" >19.1</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row11" class="row_heading level0 row11" >6 h</th>
#       <td id="T_8c649_row11_col0" class="data row11 col0" >29.3</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row12" class="row_heading level0 row12" >9 h</th>
#       <td id="T_8c649_row12_col0" class="data row12 col0" >25.2</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row13" class="row_heading level0 row13" >12 h</th>
#       <td id="T_8c649_row13_col0" class="data row13 col0" >19.6</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row14" class="row_heading level0 row14" >18 h</th>
#       <td id="T_8c649_row14_col0" class="data row14 col0" >20.2</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row15" class="row_heading level0 row15" >1 d</th>
#       <td id="T_8c649_row15_col0" class="data row15 col0" >19.3</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row16" class="row_heading level0 row16" >2 d</th>
#       <td id="T_8c649_row16_col0" class="data row16 col0" >40.7</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row17" class="row_heading level0 row17" >3 d</th>
#       <td id="T_8c649_row17_col0" class="data row17 col0" >39.8</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row18" class="row_heading level0 row18" >4 d</th>
#       <td id="T_8c649_row18_col0" class="data row18 col0" >16.2</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row19" class="row_heading level0 row19" >5 d</th>
#       <td id="T_8c649_row19_col0" class="data row19 col0" >14.0</td>
#     </tr>
#     <tr>
#       <th id="T_8c649_level0_row20" class="row_heading level0 row20" >6 d</th>
#       <td id="T_8c649_row20_col0" class="data row20 col0" >12.5</td>
#     </tr>
#   </tbody>
# </table>

# %%
sri_table_event = pd.DataFrame(index=hri.duration_steps)

hri.method = hri.METHODS.KRUEGER_PFISTER
sri_table_event[hri.METHODS.KRUEGER_PFISTER] = hri.get_event_sri_max(event[COL.START], event[COL.END])

hri.method = hri.METHODS.MUDERSBACH
sri_table_event[hri.METHODS.MUDERSBACH] = hri.get_event_sri_max(event[COL.START], event[COL.END])

hri.method = hri.METHODS.SCHMITT
sri_table_event[hri.METHODS.SCHMITT] = hri.get_event_sri_max(event[COL.START], event[COL.END])

# %% [markdown]
# Specific rain event with allocation of heavy rain indices depending on the method and duration.

# %%
cmap = ListedColormap([(1,1,1)] + list(hri.indices_color.values()))
_df = sri_table_event.astype(int).copy()
_df['max. Wiederkehrperiode'] = return_periods_frame.max()
_df['max. Regensumme'] = rainfall_sum_frame.max()
_df.rename(minutes_readable).style.\
    background_gradient(subset=[hri.METHODS.SCHMITT,
                                hri.METHODS.KRUEGER_PFISTER,
                                hri.METHODS.MUDERSBACH], cmap=cmap, vmin=0, vmax=12).\
    bar(subset=['max. Wiederkehrperiode', 'max. Regensumme'], vmin=0, vmax=100).format("{:.1f}", subset=['max. Wiederkehrperiode', 'max. Regensumme'])
# Out:
# <style type="text/css">
# #T_b6546_row0_col0, #T_b6546_row0_col1, #T_b6546_row0_col2, #T_b6546_row1_col0, #T_b6546_row1_col2, #T_b6546_row2_col0, #T_b6546_row3_col0 {
#   background-color: #b0e61a;
#   color: #000000;
# }
# #T_b6546_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.4%, transparent 1.4%);
# }
# #T_b6546_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.9%, transparent 9.9%);
# }
# #T_b6546_row1_col1, #T_b6546_row2_col1, #T_b6546_row2_col2, #T_b6546_row3_col2, #T_b6546_row4_col0, #T_b6546_row5_col0, #T_b6546_row6_col0 {
#   background-color: #ccff99;
#   color: #000000;
# }
# #T_b6546_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.6%, transparent 1.6%);
# }
# #T_b6546_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.3%, transparent 16.3%);
# }
# #T_b6546_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.1%, transparent 2.1%);
# }
# #T_b6546_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.9%, transparent 21.9%);
# }
# #T_b6546_row3_col1, #T_b6546_row4_col2, #T_b6546_row5_col2, #T_b6546_row7_col0 {
#   background-color: #e6ff4c;
#   color: #000000;
# }
# #T_b6546_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.4%, transparent 3.4%);
# }
# #T_b6546_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 28.2%, transparent 28.2%);
# }
# #T_b6546_row4_col1, #T_b6546_row6_col1, #T_b6546_row11_col0, #T_b6546_row11_col2, #T_b6546_row12_col0, #T_b6546_row12_col2, #T_b6546_row14_col0, #T_b6546_row15_col0 {
#   background-color: #ffa100;
#   color: #000000;
# }
# #T_b6546_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.4%, transparent 8.4%);
# }
# #T_b6546_row4_col4, #T_b6546_row16_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 40.7%, transparent 40.7%);
# }
# #T_b6546_row5_col1, #T_b6546_row6_col2, #T_b6546_row7_col2, #T_b6546_row8_col0, #T_b6546_row8_col2, #T_b6546_row9_col0, #T_b6546_row9_col2, #T_b6546_row10_col0, #T_b6546_row10_col2, #T_b6546_row13_col0, #T_b6546_row13_col2, #T_b6546_row14_col2, #T_b6546_row15_col2, #T_b6546_row18_col2, #T_b6546_row19_col2, #T_b6546_row20_col2 {
#   background-color: #fff500;
#   color: #000000;
# }
# #T_b6546_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.6%, transparent 6.6%);
# }
# #T_b6546_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 46.3%, transparent 46.3%);
# }
# #T_b6546_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.2%, transparent 10.2%);
# }
# #T_b6546_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 57.0%, transparent 57.0%);
# }
# #T_b6546_row7_col1, #T_b6546_row16_col2, #T_b6546_row17_col2, #T_b6546_row18_col0, #T_b6546_row19_col0, #T_b6546_row20_col0 {
#   background-color: #ff5700;
#   color: #f1f1f1;
# }
# #T_b6546_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.4%, transparent 21.4%);
# }
# #T_b6546_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 69.6%, transparent 69.6%);
# }
# #T_b6546_row8_col1, #T_b6546_row9_col1, #T_b6546_row10_col1, #T_b6546_row11_col1, #T_b6546_row12_col1, #T_b6546_row13_col1, #T_b6546_row14_col1, #T_b6546_row15_col1, #T_b6546_row16_col0, #T_b6546_row20_col1 {
#   background-color: #ff2900;
#   color: #f1f1f1;
# }
# #T_b6546_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.6%, transparent 24.6%);
# }
# #T_b6546_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 74.3%, transparent 74.3%);
# }
# #T_b6546_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.7%, transparent 20.7%);
# }
# #T_b6546_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 76.5%, transparent 76.5%);
# }
# #T_b6546_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.1%, transparent 19.1%);
# }
# #T_b6546_row10_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 78.7%, transparent 78.7%);
# }
# #T_b6546_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 29.3%, transparent 29.3%);
# }
# #T_b6546_row11_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 89.6%, transparent 89.6%);
# }
# #T_b6546_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 25.2%, transparent 25.2%);
# }
# #T_b6546_row12_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 92.8%, transparent 92.8%);
# }
# #T_b6546_row13_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.6%, transparent 19.6%);
# }
# #T_b6546_row13_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 93.0%, transparent 93.0%);
# }
# #T_b6546_row14_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.2%, transparent 20.2%);
# }
# #T_b6546_row14_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 96.4%, transparent 96.4%);
# }
# #T_b6546_row15_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.3%, transparent 19.3%);
# }
# #T_b6546_row15_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.2%, transparent 98.2%);
# }
# #T_b6546_row16_col1, #T_b6546_row17_col1 {
#   background-color: #ff1a63;
#   color: #f1f1f1;
# }
# #T_b6546_row16_col4, #T_b6546_row17_col4, #T_b6546_row18_col4, #T_b6546_row19_col4, #T_b6546_row20_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_b6546_row17_col0, #T_b6546_row18_col1, #T_b6546_row19_col1 {
#   background-color: #f71f3d;
#   color: #f1f1f1;
# }
# #T_b6546_row17_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 39.8%, transparent 39.8%);
# }
# #T_b6546_row18_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.2%, transparent 16.2%);
# }
# #T_b6546_row19_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.0%, transparent 14.0%);
# }
# #T_b6546_row20_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.5%, transparent 12.5%);
# }
# </style>
# <table id="T_b6546">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6546_level0_col0" class="col_heading level0 col0" >KruegerPfister</th>
#       <th id="T_b6546_level0_col1" class="col_heading level0 col1" >Mudersbach</th>
#       <th id="T_b6546_level0_col2" class="col_heading level0 col2" >Schmitt</th>
#       <th id="T_b6546_level0_col3" class="col_heading level0 col3" >max. Wiederkehrperiode</th>
#       <th id="T_b6546_level0_col4" class="col_heading level0 col4" >max. Regensumme</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6546_level0_row0" class="row_heading level0 row0" >5 min</th>
#       <td id="T_b6546_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_b6546_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_b6546_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_b6546_row0_col3" class="data row0 col3" >1.4</td>
#       <td id="T_b6546_row0_col4" class="data row0 col4" >9.9</td>
#     </tr>
#     <tr>
#       <th id="T_b6546_level0_row1" class="row_heading level0 row1" >10 min</th>
#       <td id="T_b6546_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_b6546_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_b6546_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_b6546_row1_col3" class="data row1 col3" >1.6</td>
#       <td id="T_b6546_row1_col4" class="data row1 col4" >16.3</td>
#     </tr>
#     <tr>
#       <th id="T_b6546_level0_row2" class="row_heading level0 row2" >15 min</th>
#       <td id="T_b6546_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_b6546_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_b6546_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_b6546_row2_col3" class="data row2 col3" >2.1</td>
#       <td id="T_b6546_row2_col4" class="data row2 col4" >21.9</td>
#     </tr>
#     <tr>
#       <th id="T_b6546_level0_row3" class="row_heading level0 row3" >20 min</th>
#       <td id="T_b6546_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_b6546_row3_col1" class="data row3 col1" >3</td>
